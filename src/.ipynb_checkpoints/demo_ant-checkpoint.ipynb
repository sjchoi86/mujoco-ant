# %% [markdown]
# # Description of Ant-V2 in MuJoCo

# %%
import gym,mujoco_py,warnings
# Remove annoying warning signs
gym.logger.set_level(40)
warnings.filterwarnings("ignore") 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline  
# %config InlineBackend.figure_format = 'retina'
from gym.envs import mujoco
np.set_printoptions(precision=3)
print ("Packages Loaded")
# Out:
# Packages Loaded

# %% [markdown]
# ### Open Ant-V2

# %%
env = mujoco.AntEnv()
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]
env.reset() # Reset 
# render_img = env.render(mode='rgb_array')
print ("Environment initialized.")
# Out:
# AntEnv-SJ
# Environment initialized.

# %% [markdown]
# ### Do some random actions

# %%
action = np.random.randn(act_dim)
obs,reward,done,r_detail = env.step(action)
render_img = env.render(mode='rgb_array')
plt.imshow(render_img)
plt.show()
print (action)
print (r_detail)
# Out:
# [ 0.61633476  0.01581731 -0.26152343  1.01492007 -1.08688279  0.35196912
#   0.81949184 -0.74928893]
# {'reward_ctrl': -2.008386599143118, 'reward_forward': -0.28320650059500097, 'reward_contact': -0.0, 'reward_survive': 1.0}

# %% [markdown]
# ### Reset the environment

# %%
# _ = env.reset()
env.set_state(env.init_qpos,env.init_qvel) # Init state
print ('==position==\n','xyz:\n',env.init_qpos[:3],'\n ornt:\n',env.init_qpos[3:7],
       '\n q:\n',env.init_qpos[7:])
print ('==velocity==\n','xyz:\n',env.init_qvel[:3],'\n ornt:\n',env.init_qvel[3:7],
       '\n q:\n',env.init_qvel[7:])
print ("Environment reset")
render_img = env.render(mode='rgb_array')
plt.imshow(render_img)
plt.show()
# Out:
# ==position==
#  xyz:
#  [0.   0.   0.75]
#  ornt:
#  [1. 0. 0. 0.]
#  q:
#  [0. 0. 0. 0. 0. 0. 0. 0.]
# ==velocity==
#  xyz:
#  [0. 0. 0.]
#  ornt:
#  [0. 0. 0. 0.]
#  q:
#  [0. 0. 0. 0. 0. 0. 0.]
# Environment reset

# %% [markdown]
# ### Run

# %%
action = np.zeros(act_dim)
# action[7] = +0.1
obs,reward,done,r_detail = env.step(action)
render_img = env.render(mode='rgb_array')
plt.imshow(render_img)
plt.show()

print ('==position==\n','z:\n',obs[:1],'\n ornt:\n',obs[1:5],
       '\n q:\n',obs[5:13])
# Out:
# ==position==
#  z:
#  [0.72]
#  ornt:
#  [1.000e+00 1.574e-17 0.000e+00 0.000e+00]
#  q:
#  [ 1.811e-20  1.272e+00 -2.509e-19 -1.272e+00 -7.552e-20 -1.272e+00
#   2.053e-19  1.272e+00]

# %%
env.frame_skip = 5
